# %% [markdown]
# <b style="font-size: 30px;">Exploratory data analysis exercise.</b><br>
# <b style="font-size: 20px;">Ejercicio de Analisis exploratorio de datos.</b>
#
# Ultra Marathon Races data set obtained from Kagle.<br>
# Data set de carreras de ultra maraton obtenidos de Kagle
#
# https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running/discussion/420633

# %%
import pandas as pd 
import seaborn as sns

# %%
#Import data from csv file to check what fields and data it contains
#Importamos los datos del archivo csv para observar que campos y datos contiene

marathon_data = pd.read_csv("./TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_1868\2654855480.py:4: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   marathon_data = pd.read_csv("./TWO_CENTURIES_OF_UM_RACES.csv")

# %%
print("Columns: "+str(marathon_data.columns))
print("Rows: "+str(marathon_data.shape))
# Out:
# Columns: Index(['Year of event', 'Event dates', 'Event name', 'Event distance/length',
#        'Event number of finishers', 'Athlete performance', 'Athlete club',
#        'Athlete country', 'Athlete year of birth', 'Athlete gender',
#        'Athlete age category', 'Athlete average speed', 'Athlete ID'],
#       dtype='object')
# Rows: (7461195, 13)

# %% [markdown]
# <b style="font-size: 30px;">Data Clean Up.</b> <br>
# <b style="font-size: 20px;">Limpieza de datos.</b>
# <br>
# For this exercise We are only interested in Colombia events<br>
# Solo nos interesan los eventos en colombia

# %%
marathon_data[marathon_data["Event name"].str.contains('(COL)', regex=False, case=False, na=False)]
# Out:
#          Year of event Event dates                           Event name  \
# 5463              2018  18.03.2018                  Pacifik Trail (COL)
# 5464              2018  18.03.2018                  Pacifik Trail (COL)
# 5465              2018  18.03.2018                  Pacifik Trail (COL)
# 5466              2018  18.03.2018                  Pacifik Trail (COL)
# 5467              2018  18.03.2018                  Pacifik Trail (COL)
# ...                ...         ...                                  ...
# 7017679           1984  04.11.1984  Pan American Race Walking Cup (COL)
# 7017680           1984  04.11.1984  Pan American Race Walking Cup (COL)
# 7017681           1984  04.11.1984  Pan American Race Walking Cup (COL)
# 7017682           1984  04.11.1984  Pan American Race Walking Cup (COL)
# 7017683           1984  04.11.1984  Pan American Race Walking Cup (COL)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
marathon_data["Year of event"].unique().sort_values();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\acer\Documents\Data Science projects\Exploratory data analysis\data_analysis.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/acer/Documents/Data%20Science%20projects/Exploratory%20data%20analysis/data_analysis.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> marathon_data["Year of event"].unique().sort_values();
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sort_values'
